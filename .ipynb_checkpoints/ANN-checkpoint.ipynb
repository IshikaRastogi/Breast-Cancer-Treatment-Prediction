# %% [markdown]
# # Importing Libraries

# %%
import ipynb

# %%
import numpy as np
import tensorflow as tf
from ipynb.fs.full.parse_dataset import Crawler
import sys
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

TEST_SIZE = 413
FEATURES = 25
OUTPUTS = 3

if __name__ == "__main__":
    n_input = 25 # MNIST data input (img shape: 28*28)
    n_treatments = 3 # MNIST total classes (0-9 digits)
    tf.compat.v1.disable_eager_execution()
    x = tf.compat.v1.placeholder("float", [None, n_input])
    y = tf.compat.v1.placeholder("float", [None, n_treatments])

# %% [markdown]
# # Data Extraction and preprocessing

# %%
    objCrawler = Crawler("FinalCancer_Data.csv")
    data = objCrawler.parse_input()
# Out:
#         PATIENT_ID  AGE_AT_DIAGNOSIS          NPI       ER_IHC  \
# count  1849.000000       1849.000000  1849.000000  1849.000000
# mean    957.274202         61.081952     4.047211     0.771769
# std     548.979903         12.958191     1.133734     0.419806
# min       1.000000         21.930000     1.020000     0.000000
# 25%     486.000000         51.420000     3.050000     1.000000
# 50%     954.000000         61.780000     4.042000     1.000000
# 75%    1435.000000         70.590000     5.042000     1.000000
# max    1904.000000         96.290000     6.360000     1.000000
#
#        INFERRED_MENOPAUSAL_STATE  BREAST_SURGERY  CHEMOTHERAPY  \
# count                1849.000000     1849.000000   1849.000000
# mean                    0.784749        0.598161      0.209843
# std                     0.411108        0.490402      0.407307
# min                     0.000000        0.000000      0.000000
# 25%                     1.000000        0.000000      0.000000
# 50%                     1.000000        1.000000      0.000000
# 75%                     1.000000        1.000000      0.000000
# max                     1.000000        1.000000      1.000000
#
#        HORMONE_THERAPY  RADIO_THERAPY         EFGR        ERBB2        BRCA1  \
# count      1849.000000    1849.000000  1849.000000  1849.000000  1849.000000
# mean          0.623580       0.603029     6.209252    10.766726     6.083678
# std           0.484618       0.489402     0.864312     1.354061     0.370507
# min           0.000000       0.000000     5.158794     6.372949     5.179831
# 25%           0.000000       0.000000     5.689939     9.975117     5.816680
# 50%           1.000000       1.000000     5.946987    10.531853     6.038121
# 75%           1.000000       1.000000     6.457609    11.151779     6.288616
# max           1.000000       1.000000    14.443632    14.643900     7.768589
#
#               CDH1         PTEN        FOXO3        BRCA2
# count  1849.000000  1849.000000  1849.000000  1849.000000
# mean      9.634349     9.924232    10.527427     5.538002
# std       1.223788     0.475811     0.612242     0.170835
# min       5.556714     7.408076     7.004775     5.061352
# 25%       9.077960     9.658676    10.149812     5.420147
# 50%       9.775422     9.977132    10.563720     5.528986
# 75%      10.423047    10.229792    10.940142     5.644537
# max      13.093380    11.479867    13.087832     6.173802

# %%
    max0 = np.amax(data[:, np.r_[0]])
    max1 = np.amax(data[:, np.r_[1]])
    max5 = np.amax(data[:, np.r_[5]])
    max6 = np.amax(data[:, np.r_[6]])
    max7 = np.amax(data[:, np.r_[7]])
    max8 = np.amax(data[:, np.r_[8]])
    max9 = np.amax(data[:, np.r_[9]])
    max10 = np.amax(data[:, np.r_[10]])
    max11 = np.amax(data[:, np.r_[11]])

    for dataElements in data:
        dataElements[0] = dataElements[0]/max0
        dataElements[1] = dataElements[1]/max1
        dataElements[5] = dataElements[5]/max5
        dataElements[6] = dataElements[6]/max6
        dataElements[7] = dataElements[7]/max7
        dataElements[8] = dataElements[8]/max8
        dataElements[9] = dataElements[9]/max9
        dataElements[10] = dataElements[10]/max10
        dataElements[11] = dataElements[11]/max11

# %% [markdown]
# # creating Train and Test data

# %%
    testInput = data[:TEST_SIZE,:FEATURES]
    testOutput = data[:TEST_SIZE, -OUTPUTS:]

    trainInput = data[TEST_SIZE:, :FEATURES]
    trainOutput = data[TEST_SIZE:, -OUTPUTS:]

    train_size = len(trainInput)

# %% [markdown]
#    # Construct model

# %%
    import keras
    from keras.models import Sequential
    from keras.layers import Dense

    classifier = Sequential()
    classifier.add(Dense(2056, activation='relu', kernel_initializer='uniform',input_dim=25))
    classifier.add(Dense(1024, activation='relu', kernel_initializer='uniform'))
    classifier.add(Dense(256, activation='relu', kernel_initializer='uniform'))
    classifier.add(Dense(3, activation='sigmoid', kernel_initializer='uniform'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    classifier.fit(trainInput, trainOutput, batch_size = 10, epochs = 100,verbose=2 )
# Out:
# Train on 1351 samples
# Epoch 1/200
# 1351/1351 - 2s - loss: 0.4349 - accuracy: 0.7915 - 2s/epoch - 1ms/sample
# Epoch 2/200
# 1351/1351 - 2s - loss: 0.3913 - accuracy: 0.8226 - 2s/epoch - 1ms/sample
# Epoch 3/200
# 1351/1351 - 2s - loss: 0.3770 - accuracy: 0.8275 - 2s/epoch - 1ms/sample
# Epoch 4/200
# 1351/1351 - 2s - loss: 0.3723 - accuracy: 0.8352 - 2s/epoch - 1ms/sample
# Epoch 5/200
# 1351/1351 - 2s - loss: 0.3706 - accuracy: 0.8305 - 2s/epoch - 1ms/sample
# Epoch 6/200
# 1351/1351 - 2s - loss: 0.3571 - accuracy: 0.8364 - 2s/epoch - 1ms/sample
# Epoch 7/200
# 1351/1351 - 2s - loss: 0.3486 - accuracy: 0.8483 - 2s/epoch - 1ms/sample
# Epoch 8/200
# 1351/1351 - 2s - loss: 0.3470 - accuracy: 0.8448 - 2s/epoch - 1ms/sample
# Epoch 9/200
# 1351/1351 - 2s - loss: 0.3464 - accuracy: 0.8485 - 2s/epoch - 2ms/sample
# Epoch 10/200
# 1351/1351 - 2s - loss: 0.3432 - accuracy: 0.8470 - 2s/epoch - 1ms/sample
# Epoch 11/200
# 1351/1351 - 2s - loss: 0.3340 - accuracy: 0.8544 - 2s/epoch - 1ms/sample
# Epoch 12/200
# 1351/1351 - 2s - loss: 0.3253 - accuracy: 0.8537 - 2s/epoch - 1ms/sample
# Epoch 13/200
# 1351/1351 - 2s - loss: 0.3256 - accuracy: 0.8566 - 2s/epoch - 1ms/sample
# Epoch 14/200
# 1351/1351 - 2s - loss: 0.3307 - accuracy: 0.8544 - 2s/epoch - 1ms/sample
# Epoch 15/200
# 1351/1351 - 2s - loss: 0.3295 - accuracy: 0.8601 - 2s/epoch - 1ms/sample
# Epoch 16/200
# 1351/1351 - 2s - loss: 0.3224 - accuracy: 0.8566 - 2s/epoch - 1ms/sample
# Epoch 17/200
# 1351/1351 - 2s - loss: 0.3132 - accuracy: 0.8613 - 2s/epoch - 1ms/sample
# Epoch 18/200
# 1351/1351 - 2s - loss: 0.3123 - accuracy: 0.8665 - 2s/epoch - 1ms/sample
# Epoch 19/200
# 1351/1351 - 2s - loss: 0.3059 - accuracy: 0.8633 - 2s/epoch - 1ms/sample
# Epoch 20/200
# 1351/1351 - 2s - loss: 0.3100 - accuracy: 0.8594 - 2s/epoch - 1ms/sample
# Epoch 21/200
# 1351/1351 - 2s - loss: 0.3006 - accuracy: 0.8700 - 2s/epoch - 1ms/sample
# Epoch 22/200
# 1351/1351 - 2s - loss: 0.2999 - accuracy: 0.8633 - 2s/epoch - 1ms/sample
# Epoch 23/200
# 1351/1351 - 2s - loss: 0.2995 - accuracy: 0.8643 - 2s/epoch - 1ms/sample
# Epoch 24/200
# 1351/1351 - 2s - loss: 0.2943 - accuracy: 0.8705 - 2s/epoch - 1ms/sample
# Epoch 25/200
# 1351/1351 - 2s - loss: 0.2961 - accuracy: 0.8608 - 2s/epoch - 1ms/sample
# Epoch 26/200
# 1351/1351 - 2s - loss: 0.2934 - accuracy: 0.8680 - 2s/epoch - 1ms/sample
# Epoch 27/200
# 1351/1351 - 2s - loss: 0.2883 - accuracy: 0.8702 - 2s/epoch - 1ms/sample
# Epoch 28/200
# 1351/1351 - 2s - loss: 0.2781 - accuracy: 0.8737 - 2s/epoch - 1ms/sample
# Epoch 29/200
# 1351/1351 - 2s - loss: 0.2777 - accuracy: 0.8761 - 2s/epoch - 1ms/sample
# Epoch 30/200
# 1351/1351 - 2s - loss: 0.2798 - accuracy: 0.8685 - 2s/epoch - 1ms/sample
# Epoch 31/200
# 1351/1351 - 2s - loss: 0.2756 - accuracy: 0.8734 - 2s/epoch - 1ms/sample
# Epoch 32/200
# 1351/1351 - 2s - loss: 0.2773 - accuracy: 0.8719 - 2s/epoch - 1ms/sample
# Epoch 33/200
# 1351/1351 - 2s - loss: 0.2748 - accuracy: 0.8707 - 2s/epoch - 1ms/sample
# Epoch 34/200
# 1351/1351 - 2s - loss: 0.2746 - accuracy: 0.8705 - 2s/epoch - 1ms/sample
# Epoch 35/200
# 1351/1351 - 2s - loss: 0.2672 - accuracy: 0.8806 - 2s/epoch - 1ms/sample
# Epoch 36/200
# 1351/1351 - 2s - loss: 0.2601 - accuracy: 0.8808 - 2s/epoch - 2ms/sample
# Epoch 37/200
# 1351/1351 - 2s - loss: 0.2642 - accuracy: 0.8791 - 2s/epoch - 1ms/sample
# Epoch 38/200
# 1351/1351 - 2s - loss: 0.2575 - accuracy: 0.8806 - 2s/epoch - 1ms/sample
# Epoch 39/200
# 1351/1351 - 2s - loss: 0.2522 - accuracy: 0.8818 - 2s/epoch - 1ms/sample
# Epoch 40/200
# 1351/1351 - 2s - loss: 0.2785 - accuracy: 0.8766 - 2s/epoch - 1ms/sample
# Epoch 41/200
# 1351/1351 - 2s - loss: 0.3028 - accuracy: 0.8645 - 2s/epoch - 1ms/sample
# Epoch 42/200
# 1351/1351 - 2s - loss: 0.2627 - accuracy: 0.8774 - 2s/epoch - 1ms/sample
# Epoch 43/200
# 1351/1351 - 2s - loss: 0.2642 - accuracy: 0.8796 - 2s/epoch - 1ms/sample
# Epoch 44/200
# 1351/1351 - 2s - loss: 0.2475 - accuracy: 0.8816 - 2s/epoch - 1ms/sample
# Epoch 45/200
# 1351/1351 - 2s - loss: 0.2511 - accuracy: 0.8806 - 2s/epoch - 1ms/sample
# Epoch 46/200
# 1351/1351 - 2s - loss: 0.2519 - accuracy: 0.8865 - 2s/epoch - 1ms/sample
# Epoch 47/200
# 1351/1351 - 2s - loss: 0.2435 - accuracy: 0.8885 - 2s/epoch - 1ms/sample
# Epoch 48/200
# 1351/1351 - 2s - loss: 0.2413 - accuracy: 0.8890 - 2s/epoch - 1ms/sample
# Epoch 49/200
# 1351/1351 - 2s - loss: 0.2373 - accuracy: 0.8900 - 2s/epoch - 1ms/sample
# Epoch 50/200
# 1351/1351 - 2s - loss: 0.2406 - accuracy: 0.8887 - 2s/epoch - 1ms/sample
# Epoch 51/200
# 1351/1351 - 2s - loss: 0.2462 - accuracy: 0.8818 - 2s/epoch - 1ms/sample
# Epoch 52/200
# 1351/1351 - 2s - loss: 0.2471 - accuracy: 0.8865 - 2s/epoch - 1ms/sample
# Epoch 53/200
# 1351/1351 - 2s - loss: 0.2380 - accuracy: 0.8860 - 2s/epoch - 1ms/sample
# Epoch 54/200
# 1351/1351 - 2s - loss: 0.2319 - accuracy: 0.8872 - 2s/epoch - 1ms/sample
# Epoch 55/200
# 1351/1351 - 2s - loss: 0.2336 - accuracy: 0.8900 - 2s/epoch - 1ms/sample
# Epoch 56/200
# 1351/1351 - 2s - loss: 0.2379 - accuracy: 0.8872 - 2s/epoch - 1ms/sample
# Epoch 57/200
# 1351/1351 - 2s - loss: 0.2251 - accuracy: 0.8969 - 2s/epoch - 1ms/sample
# Epoch 58/200
# 1351/1351 - 2s - loss: 0.2264 - accuracy: 0.8939 - 2s/epoch - 1ms/sample
# Epoch 59/200
# 1351/1351 - 2s - loss: 0.2273 - accuracy: 0.8939 - 2s/epoch - 1ms/sample
# Epoch 60/200
# 1351/1351 - 2s - loss: 0.2264 - accuracy: 0.8964 - 2s/epoch - 1ms/sample
# Epoch 61/200
# 1351/1351 - 2s - loss: 0.2249 - accuracy: 0.8924 - 2s/epoch - 1ms/sample
# Epoch 62/200
# 1351/1351 - 2s - loss: 0.2191 - accuracy: 0.9013 - 2s/epoch - 1ms/sample
# Epoch 63/200
# 1351/1351 - 2s - loss: 0.2261 - accuracy: 0.8942 - 2s/epoch - 1ms/sample
# Epoch 64/200
# 1351/1351 - 2s - loss: 0.2259 - accuracy: 0.8924 - 2s/epoch - 1ms/sample
# Epoch 65/200
# 1351/1351 - 2s - loss: 0.2249 - accuracy: 0.8939 - 2s/epoch - 1ms/sample
# Epoch 66/200
# 1351/1351 - 2s - loss: 0.2166 - accuracy: 0.8971 - 2s/epoch - 1ms/sample
# Epoch 67/200
# 1351/1351 - 2s - loss: 0.2144 - accuracy: 0.8946 - 2s/epoch - 2ms/sample
# Epoch 68/200
# 1351/1351 - 2s - loss: 0.2191 - accuracy: 0.8937 - 2s/epoch - 1ms/sample
# Epoch 69/200
# 1351/1351 - 2s - loss: 0.2179 - accuracy: 0.8966 - 2s/epoch - 1ms/sample
# Epoch 70/200
# 1351/1351 - 2s - loss: 0.2080 - accuracy: 0.9013 - 2s/epoch - 1ms/sample
# Epoch 71/200
# 1351/1351 - 2s - loss: 0.2100 - accuracy: 0.9013 - 2s/epoch - 1ms/sample
# Epoch 72/200
# 1351/1351 - 2s - loss: 0.2011 - accuracy: 0.9016 - 2s/epoch - 1ms/sample
# Epoch 73/200
# 1351/1351 - 2s - loss: 0.2134 - accuracy: 0.9028 - 2s/epoch - 1ms/sample
# Epoch 74/200
# 1351/1351 - 2s - loss: 0.2067 - accuracy: 0.9003 - 2s/epoch - 1ms/sample
# Epoch 75/200
# 1351/1351 - 2s - loss: 0.2043 - accuracy: 0.9048 - 2s/epoch - 1ms/sample
# Epoch 76/200
# 1351/1351 - 2s - loss: 0.2051 - accuracy: 0.8946 - 2s/epoch - 1ms/sample
# Epoch 77/200
# 1351/1351 - 2s - loss: 0.1980 - accuracy: 0.9023 - 2s/epoch - 1ms/sample
# Epoch 78/200
# 1351/1351 - 2s - loss: 0.1977 - accuracy: 0.9040 - 2s/epoch - 1ms/sample
# Epoch 79/200
# 1351/1351 - 2s - loss: 0.2025 - accuracy: 0.9030 - 2s/epoch - 1ms/sample
# Epoch 80/200
# 1351/1351 - 2s - loss: 0.1986 - accuracy: 0.9060 - 2s/epoch - 1ms/sample
# Epoch 81/200
# 1351/1351 - 2s - loss: 0.1982 - accuracy: 0.9045 - 2s/epoch - 1ms/sample
# Epoch 82/200
# 1351/1351 - 2s - loss: 0.2085 - accuracy: 0.9028 - 2s/epoch - 1ms/sample
# Epoch 83/200
# 1351/1351 - 2s - loss: 0.1928 - accuracy: 0.9099 - 2s/epoch - 1ms/sample
# Epoch 84/200
# 1351/1351 - 2s - loss: 0.2008 - accuracy: 0.9072 - 2s/epoch - 1ms/sample
# Epoch 85/200
# 1351/1351 - 2s - loss: 0.1937 - accuracy: 0.9060 - 2s/epoch - 1ms/sample
# Epoch 86/200
# 1351/1351 - 2s - loss: 0.2019 - accuracy: 0.9045 - 2s/epoch - 1ms/sample
# Epoch 87/200
# 1351/1351 - 2s - loss: 0.1887 - accuracy: 0.9080 - 2s/epoch - 2ms/sample
# Epoch 88/200
# 1351/1351 - 2s - loss: 0.1987 - accuracy: 0.9067 - 2s/epoch - 2ms/sample
# Epoch 89/200
# 1351/1351 - 2s - loss: 0.1879 - accuracy: 0.9062 - 2s/epoch - 1ms/sample
# Epoch 90/200
# 1351/1351 - 2s - loss: 0.1870 - accuracy: 0.9097 - 2s/epoch - 1ms/sample
# Epoch 91/200
# 1351/1351 - 2s - loss: 0.2014 - accuracy: 0.9035 - 2s/epoch - 2ms/sample
# Epoch 92/200
# 1351/1351 - 2s - loss: 0.1778 - accuracy: 0.9104 - 2s/epoch - 1ms/sample
# Epoch 93/200
# 1351/1351 - 2s - loss: 0.1906 - accuracy: 0.9070 - 2s/epoch - 1ms/sample
# Epoch 94/200
# 1351/1351 - 2s - loss: 0.1935 - accuracy: 0.9075 - 2s/epoch - 1ms/sample
# Epoch 95/200
# 1351/1351 - 2s - loss: 0.1859 - accuracy: 0.9094 - 2s/epoch - 1ms/sample
# Epoch 96/200
# 1351/1351 - 2s - loss: 0.1835 - accuracy: 0.9139 - 2s/epoch - 2ms/sample
# Epoch 97/200
# 1351/1351 - 2s - loss: 0.1880 - accuracy: 0.9060 - 2s/epoch - 1ms/sample
# Epoch 98/200
# 1351/1351 - 2s - loss: 0.1921 - accuracy: 0.9062 - 2s/epoch - 1ms/sample
# Epoch 99/200
# 1351/1351 - 2s - loss: 0.1778 - accuracy: 0.9139 - 2s/epoch - 1ms/sample
# Epoch 100/200
# 1351/1351 - 2s - loss: 0.1734 - accuracy: 0.9166 - 2s/epoch - 1ms/sample
# Epoch 101/200
# 1351/1351 - 2s - loss: 0.1683 - accuracy: 0.9188 - 2s/epoch - 2ms/sample
# Epoch 102/200
# 1351/1351 - 2s - loss: 0.1800 - accuracy: 0.9164 - 2s/epoch - 1ms/sample
# Epoch 103/200
# 1351/1351 - 2s - loss: 0.1717 - accuracy: 0.9171 - 2s/epoch - 1ms/sample
# Epoch 104/200
# 1351/1351 - 2s - loss: 0.1762 - accuracy: 0.9164 - 2s/epoch - 1ms/sample
# Epoch 105/200
# 1351/1351 - 2s - loss: 0.1697 - accuracy: 0.9173 - 2s/epoch - 1ms/sample
# Epoch 106/200
# 1351/1351 - 2s - loss: 0.1782 - accuracy: 0.9112 - 2s/epoch - 1ms/sample
# Epoch 107/200
# 1351/1351 - 2s - loss: 0.1669 - accuracy: 0.9191 - 2s/epoch - 1ms/sample
# Epoch 108/200
# 1351/1351 - 2s - loss: 0.1680 - accuracy: 0.9166 - 2s/epoch - 1ms/sample
# Epoch 109/200
# 1351/1351 - 2s - loss: 0.1999 - accuracy: 0.9077 - 2s/epoch - 1ms/sample
# Epoch 110/200
# 1351/1351 - 2s - loss: 0.1711 - accuracy: 0.9213 - 2s/epoch - 1ms/sample
# Epoch 111/200
# 1351/1351 - 2s - loss: 0.1758 - accuracy: 0.9161 - 2s/epoch - 1ms/sample
# Epoch 112/200
# 1351/1351 - 2s - loss: 0.1669 - accuracy: 0.9171 - 2s/epoch - 1ms/sample
# Epoch 113/200
# 1351/1351 - 2s - loss: 0.1626 - accuracy: 0.9203 - 2s/epoch - 1ms/sample
# Epoch 114/200
# 1351/1351 - 2s - loss: 0.1672 - accuracy: 0.9223 - 2s/epoch - 1ms/sample
# Epoch 115/200
# 1351/1351 - 2s - loss: 0.1742 - accuracy: 0.9169 - 2s/epoch - 1ms/sample
# Epoch 116/200
# 1351/1351 - 2s - loss: 0.1717 - accuracy: 0.9183 - 2s/epoch - 1ms/sample
# Epoch 117/200
# 1351/1351 - 2s - loss: 0.1638 - accuracy: 0.9220 - 2s/epoch - 1ms/sample
# Epoch 118/200
# 1351/1351 - 2s - loss: 0.1578 - accuracy: 0.9247 - 2s/epoch - 1ms/sample
# Epoch 119/200
# 1351/1351 - 2s - loss: 0.1550 - accuracy: 0.9270 - 2s/epoch - 1ms/sample
# Epoch 120/200
# 1351/1351 - 2s - loss: 0.1637 - accuracy: 0.9220 - 2s/epoch - 1ms/sample
# Epoch 121/200
# 1351/1351 - 2s - loss: 0.1540 - accuracy: 0.9275 - 2s/epoch - 1ms/sample
# Epoch 122/200
# 1351/1351 - 2s - loss: 0.1525 - accuracy: 0.9280 - 2s/epoch - 1ms/sample
# Epoch 123/200
# 1351/1351 - 2s - loss: 0.1536 - accuracy: 0.9260 - 2s/epoch - 1ms/sample
# Epoch 124/200
# 1351/1351 - 2s - loss: 0.1547 - accuracy: 0.9287 - 2s/epoch - 1ms/sample
# Epoch 125/200
# 1351/1351 - 2s - loss: 0.1542 - accuracy: 0.9245 - 2s/epoch - 1ms/sample
# Epoch 126/200
# 1351/1351 - 2s - loss: 0.1513 - accuracy: 0.9265 - 2s/epoch - 1ms/sample
# Epoch 127/200
# 1351/1351 - 2s - loss: 0.1877 - accuracy: 0.9144 - 2s/epoch - 1ms/sample
# Epoch 128/200
# 1351/1351 - 2s - loss: 0.1523 - accuracy: 0.9270 - 2s/epoch - 1ms/sample
# Epoch 129/200
# 1351/1351 - 2s - loss: 0.1473 - accuracy: 0.9280 - 2s/epoch - 1ms/sample
# Epoch 130/200
# 1351/1351 - 2s - loss: 0.1523 - accuracy: 0.9280 - 2s/epoch - 1ms/sample
# Epoch 131/200
# 1351/1351 - 2s - loss: 0.1538 - accuracy: 0.9297 - 2s/epoch - 1ms/sample
# Epoch 132/200
# 1351/1351 - 2s - loss: 0.1478 - accuracy: 0.9275 - 2s/epoch - 1ms/sample
# Epoch 133/200
# 1351/1351 - 2s - loss: 0.1750 - accuracy: 0.9188 - 2s/epoch - 1ms/sample
# Epoch 134/200
# 1351/1351 - 2s - loss: 0.1677 - accuracy: 0.9193 - 2s/epoch - 1ms/sample
# Epoch 135/200
# 1351/1351 - 2s - loss: 0.1531 - accuracy: 0.9292 - 2s/epoch - 1ms/sample
# Epoch 136/200
# 1351/1351 - 2s - loss: 0.1485 - accuracy: 0.9292 - 2s/epoch - 1ms/sample
# Epoch 137/200
# 1351/1351 - 2s - loss: 0.1357 - accuracy: 0.9358 - 2s/epoch - 1ms/sample
# Epoch 138/200
# 1351/1351 - 2s - loss: 0.1384 - accuracy: 0.9329 - 2s/epoch - 1ms/sample
# Epoch 139/200
# 1351/1351 - 2s - loss: 0.1372 - accuracy: 0.9331 - 2s/epoch - 1ms/sample
# Epoch 140/200
# 1351/1351 - 2s - loss: 0.1335 - accuracy: 0.9349 - 2s/epoch - 1ms/sample
# Epoch 141/200
# 1351/1351 - 2s - loss: 0.1332 - accuracy: 0.9331 - 2s/epoch - 2ms/sample
# Epoch 142/200
# 1351/1351 - 2s - loss: 0.1389 - accuracy: 0.9356 - 2s/epoch - 2ms/sample
# Epoch 143/200
# 1351/1351 - 2s - loss: 0.1369 - accuracy: 0.9346 - 2s/epoch - 2ms/sample
# Epoch 144/200
# 1351/1351 - 2s - loss: 0.1448 - accuracy: 0.9321 - 2s/epoch - 1ms/sample
# Epoch 145/200
# 1351/1351 - 2s - loss: 0.1690 - accuracy: 0.9265 - 2s/epoch - 1ms/sample
# Epoch 146/200
# 1351/1351 - 2s - loss: 0.1411 - accuracy: 0.9344 - 2s/epoch - 1ms/sample
# Epoch 147/200
# 1351/1351 - 2s - loss: 0.1341 - accuracy: 0.9391 - 2s/epoch - 1ms/sample
# Epoch 148/200
# 1351/1351 - 2s - loss: 0.1360 - accuracy: 0.9344 - 2s/epoch - 1ms/sample
# Epoch 149/200
# 1351/1351 - 2s - loss: 0.1482 - accuracy: 0.9289 - 2s/epoch - 1ms/sample
# Epoch 150/200
# 1351/1351 - 2s - loss: 0.1288 - accuracy: 0.9366 - 2s/epoch - 1ms/sample
# Epoch 151/200
# 1351/1351 - 2s - loss: 0.1348 - accuracy: 0.9346 - 2s/epoch - 1ms/sample
# Epoch 152/200
# 1351/1351 - 2s - loss: 0.1353 - accuracy: 0.9336 - 2s/epoch - 1ms/sample
# Epoch 153/200
# 1351/1351 - 2s - loss: 0.1431 - accuracy: 0.9359 - 2s/epoch - 1ms/sample
# Epoch 154/200
# 1351/1351 - 2s - loss: 0.1319 - accuracy: 0.9378 - 2s/epoch - 1ms/sample
# Epoch 155/200
# 1351/1351 - 2s - loss: 0.1278 - accuracy: 0.9371 - 2s/epoch - 1ms/sample
# Epoch 156/200
# 1351/1351 - 2s - loss: 0.1614 - accuracy: 0.9235 - 2s/epoch - 1ms/sample
# Epoch 157/200
# 1351/1351 - 2s - loss: 0.1328 - accuracy: 0.9371 - 2s/epoch - 1ms/sample
# Epoch 158/200
# 1351/1351 - 2s - loss: 0.1221 - accuracy: 0.9452 - 2s/epoch - 1ms/sample
# Epoch 159/200
# 1351/1351 - 2s - loss: 0.1187 - accuracy: 0.9423 - 2s/epoch - 1ms/sample
# Epoch 160/200
# 1351/1351 - 2s - loss: 0.1199 - accuracy: 0.9447 - 2s/epoch - 1ms/sample
# Epoch 161/200
# 1351/1351 - 2s - loss: 0.1382 - accuracy: 0.9378 - 2s/epoch - 1ms/sample
# Epoch 162/200
# 1351/1351 - 2s - loss: 0.1190 - accuracy: 0.9410 - 2s/epoch - 1ms/sample
# Epoch 163/200
# 1351/1351 - 2s - loss: 0.1130 - accuracy: 0.9467 - 2s/epoch - 1ms/sample
# Epoch 164/200
# 1351/1351 - 2s - loss: 0.1354 - accuracy: 0.9324 - 2s/epoch - 1ms/sample
# Epoch 165/200
# 1351/1351 - 2s - loss: 0.1273 - accuracy: 0.9405 - 2s/epoch - 1ms/sample
# Epoch 166/200
# 1351/1351 - 2s - loss: 0.1283 - accuracy: 0.9423 - 2s/epoch - 1ms/sample
# Epoch 167/200
# 1351/1351 - 2s - loss: 0.1202 - accuracy: 0.9430 - 2s/epoch - 1ms/sample
# Epoch 168/200
# 1351/1351 - 2s - loss: 0.1148 - accuracy: 0.9440 - 2s/epoch - 1ms/sample
# Epoch 169/200
# 1351/1351 - 2s - loss: 0.1289 - accuracy: 0.9351 - 2s/epoch - 2ms/sample
# Epoch 170/200
# 1351/1351 - 2s - loss: 0.1213 - accuracy: 0.9447 - 2s/epoch - 2ms/sample
# Epoch 171/200
# 1351/1351 - 2s - loss: 0.1193 - accuracy: 0.9435 - 2s/epoch - 2ms/sample
# Epoch 172/200
# 1351/1351 - 2s - loss: 0.1150 - accuracy: 0.9435 - 2s/epoch - 1ms/sample
# Epoch 173/200
# 1351/1351 - 2s - loss: 0.1127 - accuracy: 0.9472 - 2s/epoch - 1ms/sample
# Epoch 174/200
# 1351/1351 - 2s - loss: 0.1078 - accuracy: 0.9487 - 2s/epoch - 1ms/sample
# Epoch 175/200
# 1351/1351 - 2s - loss: 0.1193 - accuracy: 0.9435 - 2s/epoch - 1ms/sample
# Epoch 176/200
# 1351/1351 - 2s - loss: 0.1074 - accuracy: 0.9482 - 2s/epoch - 1ms/sample
# Epoch 177/200
# 1351/1351 - 2s - loss: 0.1109 - accuracy: 0.9524 - 2s/epoch - 1ms/sample
# Epoch 178/200
# 1351/1351 - 2s - loss: 0.1229 - accuracy: 0.9413 - 2s/epoch - 1ms/sample
# Epoch 179/200
# 1351/1351 - 2s - loss: 0.1173 - accuracy: 0.9437 - 2s/epoch - 1ms/sample
# Epoch 180/200
# 1351/1351 - 2s - loss: 0.1179 - accuracy: 0.9455 - 2s/epoch - 1ms/sample
# Epoch 181/200
# 1351/1351 - 2s - loss: 0.1144 - accuracy: 0.9479 - 2s/epoch - 1ms/sample
# Epoch 182/200
# 1351/1351 - 2s - loss: 0.1243 - accuracy: 0.9396 - 2s/epoch - 1ms/sample
# Epoch 183/200
# 1351/1351 - 2s - loss: 0.1109 - accuracy: 0.9465 - 2s/epoch - 1ms/sample
# Epoch 184/200
# 1351/1351 - 2s - loss: 0.1468 - accuracy: 0.9329 - 2s/epoch - 1ms/sample
# Epoch 185/200
# 1351/1351 - 2s - loss: 0.1563 - accuracy: 0.9321 - 2s/epoch - 1ms/sample
# Epoch 186/200
# 1351/1351 - 2s - loss: 0.1269 - accuracy: 0.9386 - 2s/epoch - 1ms/sample
# Epoch 187/200
# 1351/1351 - 2s - loss: 0.0983 - accuracy: 0.9541 - 2s/epoch - 1ms/sample
# Epoch 188/200
# 1351/1351 - 2s - loss: 0.1103 - accuracy: 0.9482 - 2s/epoch - 1ms/sample
# Epoch 189/200
# 1351/1351 - 2s - loss: 0.1043 - accuracy: 0.9509 - 2s/epoch - 1ms/sample
# Epoch 190/200
# 1351/1351 - 2s - loss: 0.0996 - accuracy: 0.9529 - 2s/epoch - 1ms/sample
# Epoch 191/200
# 1351/1351 - 2s - loss: 0.1074 - accuracy: 0.9497 - 2s/epoch - 1ms/sample
# Epoch 192/200
# 1351/1351 - 2s - loss: 0.1041 - accuracy: 0.9509 - 2s/epoch - 1ms/sample
# Epoch 193/200
# 1351/1351 - 2s - loss: 0.0965 - accuracy: 0.9556 - 2s/epoch - 1ms/sample
# Epoch 194/200
# 1351/1351 - 2s - loss: 0.1025 - accuracy: 0.9526 - 2s/epoch - 1ms/sample
# Epoch 195/200
# 1351/1351 - 2s - loss: 0.1009 - accuracy: 0.9529 - 2s/epoch - 1ms/sample
# Epoch 196/200
# 1351/1351 - 2s - loss: 0.1081 - accuracy: 0.9502 - 2s/epoch - 1ms/sample
# Epoch 197/200
# 1351/1351 - 2s - loss: 0.1269 - accuracy: 0.9420 - 2s/epoch - 1ms/sample
# Epoch 198/200
# 1351/1351 - 2s - loss: 0.1097 - accuracy: 0.9494 - 2s/epoch - 1ms/sample
# Epoch 199/200
# 1351/1351 - 2s - loss: 0.0926 - accuracy: 0.9583 - 2s/epoch - 1ms/sample
# Epoch 200/200
# 1351/1351 - 2s - loss: 0.0898 - accuracy: 0.9571 - 2s/epoch - 1ms/sample

# %% [markdown]
# # Testing Model

# %%
y_pred = classifier.predict(testInput)
y_pred = (y_pred > 0.30)
print(y_pred)
# Out:
# [[False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True False]
#  [False  True  True]
#  [ True False  True]
#  [False  True  True]
#  [False False  True]
#  [ True  True False]
#  [False  True  True]
#  [False  True False]
#  [False  True False]
#  [False  True  True]
#  [ True False False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [False False  True]
#  [False  True  True]
#  [ True  True  True]
#  [False  True False]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [ True  True  True]
#  [ True  True False]
#  [False  True False]
#  [False False  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [False False  True]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [ True  True  True]
#  [False False  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [ True  True False]
#  [False  True  True]
#  [False False  True]
#  [False  True False]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True False]
#  [ True  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [ True  True  True]
#  [False  True  True]
#  [False  True False]
#  [ True False  True]
#  [ True  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [ True False  True]
#  [ True  True  True]
#  [False  True  True]
#  [ True False  True]
#  [False  True False]
#  [ True  True  True]
#  [ True  True  True]
#  [False  True  True]
#  [ True  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True False  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False False  True]
#  [False  True  True]
#  [ True  True False]
#  [False False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [False  True False]
#  [False False  True]
#  [ True False  True]
#  [False  True  True]
#  [ True  True  True]
#  [False  True  True]
#  [False False  True]
#  [ True  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False False  True]
#  [ True  True  True]
#  [False  True False]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [ True  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True False]
#  [ True  True False]
#  [False  True  True]
#  [ True  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [False  True  True]
#  [False  True False]
#  [ True False  True]
#  [False  True  True]
#  [ True  True  True]
#  [ True False  True]
#  [False  True  True]
#  [ True False  True]
#  [ True  True  True]
#  [False  True False]
#  [ True  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]
#  [ True  True  True]
#  [ True False  True]
#  [ True False  True]
#  [False  True False]
#  [ True  True  True]
#  [False  True  True]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [ True  True  True]
#  [ True  True False]
#  [ True False  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False False  True]
#  [False  True False]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True  True]
#  [False  True False]]

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

confusion_matrix_A = multilabel_confusion_matrix(testOutput, y_pred)[0]
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts1 = ["{0:0.0f}".format(value) for value in
                confusion_matrix_A.flatten()]
group_percentages1 = ["{0:.2%}".format(value) for value in
                     confusion_matrix_A.flatten()/np.sum(confusion_matrix_A)]
labels1 = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts1,group_percentages1)]
labels1 = np.asarray(labels1).reshape(2,2)
plt.figure(figsize=(8,5))
ax = sns.heatmap(confusion_matrix_A, annot=labels1, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix for chemo therapy');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.tight_layout()  
plt.show()

confusion_matrix_B = multilabel_confusion_matrix(testOutput, y_pred)[1]
group_counts2 = ["{0:0.0f}".format(value) for value in
                confusion_matrix_B.flatten()]
group_percentages2 = ["{0:.2%}".format(value) for value in
                     confusion_matrix_B.flatten()/np.sum(confusion_matrix_B)]
labels2 = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts2,group_percentages2)]
labels2 = np.asarray(labels2).reshape(2,2)
plt.figure(figsize=(8,5))
ax = sns.heatmap(confusion_matrix_B, annot=labels2, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix for Hormone therapy');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.tight_layout()
plt.show()

confusion_matrix_C = multilabel_confusion_matrix(testOutput, y_pred)[2]
group_counts3 = ["{0:0.0f}".format(value) for value in
                confusion_matrix_C.flatten()]
group_percentages3 = ["{0:.2%}".format(value) for value in
                     confusion_matrix_C.flatten()/np.sum(confusion_matrix_C)]
labels3 = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts3,group_percentages3)]
labels3 = np.asarray(labels3).reshape(2,2)
plt.figure(figsize=(8,5))
ax = sns.heatmap(confusion_matrix_C, annot=labels3, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix for Radio therapy');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing Accracy

# %%
  def Accuracy(y_true, y_pred):
    temp = 0
    for i in range(y_true.shape[1]):
        temp += sum(np.logical_and(y_true[i], y_pred[i])) / sum(np.logical_or(y_true[i], y_pred[i]))
    return temp / y_true.shape[1]
    
  Accuracy(testOutput, y_pred)
# Out:
# 0.7777777777777778

# %% [markdown]
# # Precision, Recall, F1 Measure

# %%
def Precision(y_true, y_pred):
    temp = 0
    for i in range(y_true.shape[0]):
        
        if sum(y_true[i]) == 0:
            continue
        temp+= sum(np.logical_and(y_true[i], y_pred[i]))/ sum(y_true[i])
    return temp/ y_true.shape[0]
p = Precision(testOutput, y_pred)

def Recall(y_true, y_pred):
    temp = 0
    for i in range(y_true.shape[0]):
        if sum(y_pred[i]) == 0:
            continue
        temp+= sum(np.logical_and(y_true[i], y_pred[i]))/ sum(y_pred[i])
    return temp/ y_true.shape[0]
r = Recall(testOutput,y_pred)

def F1Measure(y_true, y_pred):
    temp = 0
    for i in range(y_true.shape[0]):
        if (sum(y_true[i]) == 0) and (sum(y_pred[i]) == 0):
            continue
        temp+= (2*sum(np.logical_and(y_true[i], y_pred[i])))/ (sum(y_true[i])+sum(y_pred[i]))
    return temp/ y_true.shape[0]
    
F1 = F1Measure(testOutput, y_pred)

print ("Precision = ",end="")
print ('%.3f'%p)
print ("Recall = ",end="")
print ('%.3f'%r)
print ("F1 Measure = ",end="")
print ('%.3f'%F1)
# Out:
# Precision = 0.819
# Recall = 0.887
# F1 Measure = 0.814

# %% [markdown]
# # Classification report

# %%
from sklearn.metrics import classification_report
label_names = ['CHEMO_THERAPY', 'HORMONE_THERAPY', 'RADIO_THERAPY']
print(classification_report(testOutput, y_pred,target_names=label_names))
# Out:
#                  precision    recall  f1-score   support
#
#   CHEMO_THERAPY       0.79      0.46      0.58        83
# HORMONE_THERAPY       0.93      0.95      0.94       201
#   RADIO_THERAPY       0.82      0.77      0.80       186
#
#       micro avg       0.87      0.79      0.83       470
#       macro avg       0.85      0.73      0.77       470
#    weighted avg       0.86      0.79      0.82       470
#     samples avg       0.89      0.82      0.81       470

# %% [markdown]
# # Prediction for single instance

# %%
y1 = classifier.predict(testInput[10:11])
y1 = (y1 > 0.3)
for i in range(len(y1)):
    for j in range(len(y1[i])):
        if j == 0:
            if y1[i][j] == True:
                print("CHEMOTHERAPY",end=",")
        if j == 1:
            if y1[i][j] == True:
                print("HORMONE THERAPY",end=",")
        if j == 2:
            if y1[i][j] == True:
                print("RADIO THERAPY",end=",")
    print()
# Out:
# HORMONE THERAPY,RADIO THERAPY,
